# %% [markdown]
# ### Test0, Test2, Test7
# This script plots results from three 1D tests runs. These tests are required to produce inputs for 2D and 3D cases.
#
# Authors: Ethan Coon and Elchin Jafarov

# %%
# %matplotlib inline
import sys,os
sys.path.append(os.path.join(os.environ['ATS_SRC_DIR'],'tools', 'utils'))
import parse_xmf
import column_data
import colors
import numpy as np
import matplotlib.cm
from matplotlib import pyplot as plt

# %% [markdown]
# This example is designed to simulate discontinuous warm permafrost with a flux (-1e-07) at the bottom boundary.
# test0 is similar to the 1Dcolumn.

# %%
def plot(directory, axs, style):
    dati = column_data.column_data(["pressure", "saturation_liquid"],
                              keys=1, directory=directory)
    z = dati[0,0,:]

    axs[0,1].plot(dati[1,0,:],z, style)
    axs[0,0].plot(dati[2,0,:],z, style)

    # zoom in
    axs[1,1].plot(dati[1,0,:],z, style)
    axs[1,0].plot(dati[2,0,:],z, style)

fig, axs = plt.subplots(2,2, figsize=(11,8))
dii = "test0/test0.regression"
plot(dii, axs, 'r--')

axs[0,0].set_xlim([-.1,1.1])
axs[0,0].set_xlabel('saturation [-]')
axs[0,0].set_ylabel('z-coordinate [m]')
axs[0,1].set_xlabel('pressure [Pa]')
axs[0,1].set_ylabel('z-coordinate [m]')
axs[0,1].ticklabel_format(style='sci', axis='x', scilimits=(0,0))

axs[1,0].set_ylim([-5,0])
axs[1,1].set_ylim([-5,0])
#axs[1,0].set_xlim([-.1,1.1])
#axs[1,1].set_xlim([0.5,1.5e5])
axs[1,0].set_xlabel('saturation [-]')
axs[1,0].set_ylabel('z-coordinate [m]')
axs[1,1].set_xlabel('pressure [Pa]')
axs[1,1].set_ylabel('z-coordinate [m]')
axs[1,1].ticklabel_format(style='sci', axis='x', scilimits=(0,0))

plt.tight_layout()
plt.show()

# %% [markdown]
# #### test2: Freeze steady-state to generate ice column

# %% [markdown]
# Transient simulations are initialized in the winter to make spinup simpler.  Here we start with temperature of 271.15K = -2C at the top and flux at the bottom boundary.
#
# In this case the lower boundary stays unfrozen and gas does not accumulates there.
#
# The overall temprature profile with depth changes now from -2C at top to -2.5C at the bottom boundary.
#
# NOTE: From here on, transient problems are plotted such that early times have low saturation, and late times are high saturation.

# %%
# plot the solution

def plot(directory, axs, style):
    # load the data
    dati = column_data.column_data(["pressure", "saturation_liquid", 
                                    "saturation_ice", "saturation_gas", "temperature"],
                                    directory=directory)
    keys, times, dat = parse_xmf.readATS(directory=directory)

    ice = colors.cm_mapper(-10000, times[-1], colors.ice_cmap())
    water = colors.cm_mapper(-10000, times[-1], colors.water_cmap())
    gas = colors.cm_mapper(-10000, times[-1], colors.gas_cmap())    
    
    # plot saturation of liquid, pressure
    z = dati[0,0,:]
    for i,t in enumerate(times):
        axs[2].plot(dati[5,i,:]- 273.15,z, style, color=gas(t))
        axs[1].plot(dati[1,i,:],z, style, color=water(t))
        axs[0].plot(dati[2,i,:],z, style, color=water(t)) #dark blue
        axs[0].plot(dati[3,i,:],z, style, color=ice(t)) #light blue
        axs[0].plot(dati[4,i,:],z, style, color=gas(t)) #dark red
    axs[2].plot(dati[5,i,:]*0,z, style, color=gas(t))
    
def plot_resutls(diii):      
    fig, axs = column_data.getFigs(False, True)
    plot(diii, axs, '-')

    axs[0].set_xlim([-.1,1.1])
    axs[0].set_xlabel('saturation [-]')
    axs[0].set_ylabel('z-coordinate [m]')
    axs[1].set_xlabel('pressure [Pa]')
    axs[2].set_xlabel('temperature [C]')
    axs[1].ticklabel_format(style='sci', axis='x', scilimits=(0,0))

    # and the zoomed version
    fig, axs = column_data.getFigs(False, True)

    plot(diii, axs, '-')

    axs[0].set_xlim([-.1,1.1])
    axs[0].set_xlabel('saturation [-]')
    axs[0].set_ylabel('z-coordinate [m]')
    axs[1].set_xlabel('pressure [Pa]')
    axs[2].set_xlabel('temperature [K]')
    axs[1].ticklabel_format(style='sci', axis='x', scilimits=(0,0))

    axs[0].set_ylim([-5,-0])
    axs[1].set_ylim([-5,-0])
    axs[2].set_ylim([-5,-0])

    plt.show()

# %% [markdown]
# Here we test for the 3 type of state conditions: default, constant ice density, and constant liquid and ice density. The objective is to compare the performances and pressure with depth profiles. All test are driven with same initial and boundary value conditions. Initial soil saturation was taken from the test0. T_initial= 0C, T_surface= -1C, T_bottom= 1C. The main difference is pressure profile. I run it multiple times in all cases constant ice density case outperform other two cases.

# %%
plot_resutls("test2/test2.default.regression")

# %%
plot_resutls("test2/test2.ice_const.regression")

# %%
plot_resutls("test2/test2.liq_ice_const.regression")

# %%
# !tail {"-10 test2/test2.default.regression/std.out"}
# Out:
#            |  ================================================================================
#            |
#            |                        TimeMonitor results over 1 processor
#            |
#            |  Timer Name              Global time (num calls)
#            |  --------------------------------------------------------------------------------
#            |  cycle                   60.15 (1)
#            |  setup                   0.01975 (1)
#            |  volume mesh creation    0.005525 (0)
#            |  ================================================================================

# %%
# !tail {"-10 test2/test2.ice_const.regression/std.out"}
# Out:
#            |  ================================================================================
#            |
#            |                        TimeMonitor results over 1 processor
#            |
#            |  Timer Name              Global time (num calls)
#            |  --------------------------------------------------------------------------------
#            |  cycle                   42.87 (1)
#            |  setup                   0.02096 (1)
#            |  volume mesh creation    0.005995 (0)
#            |  ================================================================================

# %%
# !tail {"-10 test2/test2.liq_ice_const.regression/std.out"}
# Out:
#            |  ================================================================================
#            |
#            |                        TimeMonitor results over 1 processor
#            |
#            |  Timer Name              Global time (num calls)
#            |  --------------------------------------------------------------------------------
#            |  cycle                   56.08 (1)
#            |  setup                   0.02201 (1)
#            |  volume mesh creation    0.005863 (0)
#            |  ================================================================================

# %% [markdown]
# #### test7: SEB, permafrost surface and subsurface flow
#
# Runs for 10 years. Initial conditions (ICs) for flow and energy equations come from test2. SEB uses simplifed (smoothed) meteorological data. Here I used three cases: default configuration using ICs from default test2, default configuration using ICs from ice-const test2, and ice-const configuration using ICs from ice-const test2. The extra pressure spike was introducing for first 2 cases. 3 case does not have any pressure jumps. In addition, last cases runs almost 3 faster than others.

# %%
plot_resutls("test7/test7.default.regression")

# %%
plot_resutls("test7/test7.default_ice_const.regression")

# %%
plot_resutls("test7/test7.ice_const.regression")

# %%
# !tail {"-10 std-files/std-default.out"}
# Out:
#            |  ================================================================================
#            |
#            |                        TimeMonitor results over 1 processor
#            |
#            |  Timer Name              Global time (num calls)
#            |  --------------------------------------------------------------------------------
#            |  cycle                   1669 (1)
#            |  setup                   0.0537 (1)
#            |  volume mesh creation    0.005725 (0)
#            |  ================================================================================

# %%
# !tail {"-10 std-files/std-def-ice-const.out"}
# Out:
#            |  ================================================================================
#            |
#            |                        TimeMonitor results over 1 processor
#            |
#            |  Timer Name              Global time (num calls)
#            |  --------------------------------------------------------------------------------
#            |  cycle                   1719 (1)
#            |  setup                   0.04879 (1)
#            |  volume mesh creation    0.005152 (0)
#            |  ================================================================================

# %%
# !tail {"-10 std-files/std-ice-const.out"}
# Out:
#            |  ================================================================================
#            |
#            |                        TimeMonitor results over 1 processor
#            |
#            |  Timer Name              Global time (num calls)
#            |  --------------------------------------------------------------------------------
#            |  cycle                   682.5 (1)
#            |  setup                   0.05201 (1)
#            |  volume mesh creation    0.005351 (0)
#            |  ================================================================================
